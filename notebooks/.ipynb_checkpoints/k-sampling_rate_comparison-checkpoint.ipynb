# %% [markdown]
# ## Exploratory Data Analysis

# %%
# imports
import os
import pandas as pd 
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np
from sklearn import preprocessing

# %% [markdown]
# We load three datasets, all recorded from the CWRU experiment @ 3 HP (~1730 RPM), recorded for approx. 10s using the Drive End accelerometer:
#
# - fault_12k: 0.021" ball fault time series sampled at 12kHz
# - fault_48k: 0.021" ball fault time series sampled at 48kHz
# - normal_48k: Normal baseline time series sampled at 48kHz

# %%
FILE_PATH = ["..", "data", "processed"]

def load_data(file_name, data):
    """load data file into the "data" dict, file name as key
    """
    key = file_name.split('.')[0]
    data[key] = pd.read_csv(os.sep.join(FILE_PATH + [file_name]), header=None)

DATA = {}

for f in ['b021_3_12_DE.csv', 'b021_3_48_DE.csv', 'normal_3_48_DE.csv']:
    load_data(f, DATA)

# # load data in 
# fault_12k = pd.read_csv(os.sep.join(FILE_PATH + ['b021_3_12_DE.csv']), header=None)
# fault_48k = pd.read_csv(os.sep.join(FILE_PATH + ['b021_3_48_DE.csv']), header=None)
# normal_48k = pd.read_csv(os.sep.join(FILE_PATH + ['normal_3_48_DE.csv']), header=None)

# %%
def display_data_stat(data):
    stat_info = ['size', 'min', 'max', 'mean', 'avg power']
    head_fmt = "{:25}"+"{:15}"*len(stat_info)
    line_fmt = "{:15}"+"{:15}"+"{:15.3f}"*(len(stat_info)-1)
    print(head_fmt.format("", *stat_info))
    for k, v in data.items():
        v = v[0]
        print(line_fmt.format(k, len(v), np.min(v), np.max(v), np.mean(v), np.var(v)))
    
display_data_stat(DATA)
# Out:
#                          size           min            max            mean           avg power
# b021_3_12_DE            122136         -0.493          0.576          0.004          0.014
# b021_3_48_DE            486804         -3.418          3.418          0.012          0.104
# normal_3_48_DE          485643         -0.306          0.284          0.012          0.004

# %%
def unify_data(data):
    for k, v in data.items():
        v_ = np.array(v[0]).reshape(-1, 1)
        v_ = preprocessing.StandardScaler().fit_transform(v_)
        data[k] = pd.DataFrame(data=list(v_))

unify_data(DATA)
display_data_stat(DATA)
# Out:
#                          size           min            max            mean           avg power
# b021_3_12_DE            122136         -4.221          4.851          0.000          1.000
# b021_3_48_DE            486804        -10.638         10.564          0.000          1.000
# normal_3_48_DE          485643         -4.930          4.193         -0.000          1.000

# %%
def display_spetrum(data):
    for k, v in data.items():
        v = v[0]
        s = np.abs(np.fft.fft(v))
        s = np.log(s)
        n = round(len(s)/2)
        plt.figure()
        plt.plot(range(n-1), s[1:n], label=k+':spectrum')

display_spetrum(DATA)

# %%
def add_WGN(data, snr):
    """add Gaussian White Noise
    PARAMATER:
        data: DataFrame with unified signal value
        snr: SNR
    """
    amp = 10**snr
    for k, v in data.items():
        v_ = v[0]
        n = np.random.normal(0, snr, size=len(v))
        data[k] = pd.DataFrame(data=list(np.add(n, v_)))

        
add_WGN(DATA, 3)
display_spetrum(DATA)

# %%
# rename columns and add time column 
fault_12k = fault_12k.rename(columns={0: 'accel'})
fault_48k = fault_48k.rename(columns={0: 'accel'})
normal_48k = normal_48k.rename(columns={0: 'accel'})

fault_12k['time'] = fault_12k.index
fault_48k['time'] = fault_48k.index
normal_48k['time'] = normal_48k.index

# %%
# define plotting function
def plot_ts(ts, title, dt):
    plt.plot(ts.index*dt, ts['accel'], label='sig')
    plt.xlabel('time (s)')
    plt.ylabel('accel ($m/s^2$)')
    plt.title(title)

# %%
# plot time series
dt = 1/12000
plot_ts(fault_12k, '0.021" Ball Fault @ 12kHz and 1730 RPM', dt)

# %%
dt = 1/48000
plot_ts(fault_48k, '0.021" Ball Fault @ 48kHz and 1730 RPM', dt)

# %%
dt = 1/48000
plot_ts(normal_48k, 'Baseline @ 48kHz and 1730 RPM', dt)

# %%
# downsample 48k normal to approx. 12k
# normal_12k_val = signal.decimate(normal_48k.accel.values.T, 4)

# %%
normal_12k_val = normal_48k.accel.values[0::4]

# %%
normal_12k_val.shape
# Out:
# (121411,)

# %%
normal_12k = pd.DataFrame(normal_12k_val, columns=['accel'])
normal_12k['time'] = normal_12k.index

# %%
normal_12k
# Out:
#            accel    time
# 0       0.014603       0
# 1       0.112650       1
# 2       0.127670       2
# 3       0.046938       3
# 4      -0.000209       4
# ...          ...     ...
# 121406 -0.070929  121406
# 121407 -0.048816  121407
# 121408  0.016898  121408
# 121409  0.044435  121409
# 121410 -0.023574  121410
#
# [121411 rows x 2 columns]

# %%
# plot time series
dt = 1/12000
plot_ts(normal_12k, 'Baseline @ 12kHz and 1730 RPM', dt)

# %%
# plot first 100 points
normal_12k.accel[:100].plot()
# Out:
# <AxesSubplot:>

# %%
# plot first 400 points
normal_48k.accel[:400].plot()
# Out:
# <AxesSubplot:>

# %%
# create new column assigning an individual id to windows of sizes corresponding to 1 rev 
normal_48k['id'] = np.array(normal_48k.index/1665, np.int32) 
fault_48k['id'] = np.array(fault_48k.index/1665, np.int32)
normal_12k['id'] = np.array(normal_12k.index/416, np.int32)
fault_12k['id'] = np.array(fault_12k.index/416, np.int32)

# %%
fault_48k
# Out:
#            accel    time   id
# 0       0.099301       0    0
# 1       0.066131       1    0
# 2       0.027120       2    0
# 3      -0.013143       3    0
# 4      -0.057578       4    0
# ...          ...     ...  ...
# 486799  0.187130  486799  292
# 486800  0.142900  486800  292
# 486801  0.080526  486801  292
# 486802  0.004798  486802  292
# 486803 -0.042558  486803  292
#
# [486804 rows x 3 columns]

# %% [markdown]
# ## Extract Features

# %% [markdown]
# The extract_features function takes a while, so skip this section if already have preprocessed data files.

# %%
from tsfresh.feature_extraction import extract_features

# X_f48k = extract_features(fault_48k, column_id='id', column_sort='time')
# X_n48k = extract_features(normal_48k, column_id='id', column_sort='time')
# X_f12k = extract_features(fault_12k, column_id='id', column_sort='time')
# X_n12k = extract_features(normal_12k, column_id='id', column_sort='time')
# Out:
# Feature Extraction: 100%|██████████████████████████████████████████████████████████████| 20/20 [00:45<00:00,  2.26s/it]

# %%
# X_f48k = pd.read_csv('X_f48k.csv').drop(columns=['Unnamed: 0'])
# X_n48k = pd.read_csv('X_n48k.csv').drop(columns=['Unnamed: 0'])
# X_f12k = pd.read_csv('X_f12k.csv').drop(columns=['Unnamed: 0'])
# X_n12k = pd.read_csv('X_n12k.csv').drop(columns=['Unnamed: 0'])

# %%
# X_f48k

# %%
X_48k = pd.concat([X_f48k, X_n48k], ignore_index=True)
X_12k = pd.concat([X_f12k, X_n12k], ignore_index=True)

# %%
y_48k = np.zeros((len(X_48k),1)) # create labels
y_48k[:len(X_f48k)] = '1'
y_48k[len(X_f48k):len(X_48k)] = '0'

# %%
y_12k = np.zeros((len(X_12k),1))
y_12k[:len(X_f12k)] = '1'
y_12k[len(X_f12k):len(X_48k)] = '0'

# %%
X_48k.shape
# Out:
# (585, 789)

# %%
X_48k_real = X_48k.dropna(axis=1) # drop columns with NaN
X_12k_real = X_12k.dropna(axis=1) # drop columns with NaN

# %%
from tsfresh.transformers import FeatureSelector

select = FeatureSelector() # we want to select only relevant features for prediction

# %%
select.fit(X_48k_real, np.squeeze(y_48k))
# Out:
# FeatureSelector()

# %%
p_values = pd.Series(select.p_values, index=select.features)
p_values
# Out:
# accel__number_peaks__n_3                           1.715860e-97
# accel__number_peaks__n_1                           2.088411e-97
# accel__number_crossing_m__m_0                      2.694570e-97
# accel__fourier_entropy__bins_10                    2.749926e-97
# accel__ratio_value_number_to_time_series_length    2.909644e-97
#                                                        ...
# accel__fft_coefficient__attr_"imag"__coeff_0                NaN
# accel__fft_coefficient__attr_"angle"__coeff_0               NaN
# accel__value_count__value_1                                 NaN
# accel__value_count__value_-1                                NaN
# accel__ratio_beyond_r_sigma__r_10                           NaN
# Length: 788, dtype: float64

# %%
len(select.relevant_features)
# Out:
# 309

# %%
X_48k_rel = select.transform(X_48k_real)
X_48k_rel.shape
# Out:
# (585, 309)

# %%
select.fit(X_12k_real, np.squeeze(y_12k))
# Out:
# FeatureSelector()

# %%
X_12k_rel = select.transform(X_12k_real)
X_12k_rel.shape
# Out:
# (586, 299)

# %%
X_48k_rel['label'] = np.int32(y_48k)
X_12k_rel['label'] = np.int32(y_12k)

# %%
X_48k_rel.to_csv('48k_proc.csv', index=False)
X_12k_rel.to_csv('12k_proc.csv', index=False)

# %% [markdown]
# ## Fit Model on 12k dataset

# %%
# load in preprocessed data 
df_12k = pd.read_csv('12k_proc.csv')
df_48k = pd.read_csv('48k_proc.csv')

# %%
df_12k
# Out:
#      accel__has_duplicate  accel__ratio_value_number_to_time_series_length  \
# 0                     1.0                                         0.927885
# 1                     1.0                                         0.918269
# 2                     1.0                                         0.913462
# 3                     1.0                                         0.918269
# 4                     1.0                                         0.927885
# ..                    ...                                              ...
# 581                   0.0                                         1.000000
# 582                   0.0                                         1.000000
# 583                   0.0                                         1.000000
# 584                   0.0                                         1.000000
# 585                   0.0                                         1.000000
#
#      accel__percentage_of_reoccurring_datapoints_to_all_datapoints  \
# 0                                             0.139423
# 1                                             0.151442
# 2                                             0.165865
# 3                                             0.158654
# 4                                             0.141827
# ..                                                 ...
# 581                                           0.000000
# 582                                           0.000000
# 583                                           0.000000
# 584                                           0.000000
# 585                                           0.000000
#
#      accel__percentage_of_reoccurring_values_to_all_values  \
# 0                                             0.072539
# 1                                             0.075916
# 2                                             0.086842
# 3                                             0.083770
# 4                                             0.075130
# ..                                                 ...
# 581                                           0.000000
# 582                                           0.000000
# 583                                           0.000000
# 584                                           0.000000
# 585                                           0.000000
#
#      accel__quantile__q_0.4  accel__quantile__q_0.8  accel__quantile__q_0.2  \
# 0                 -0.017543                0.093075               -0.106720
# 1                 -0.026477                0.100220               -0.083492
# 2                 -0.023878                0.099898               -0.098761
# 3                 -0.027776                0.104120               -0.093075
# 4                 -0.025015                0.099573               -0.086253
# ..                      ...                     ...                     ...
# 581                0.001236                0.057384               -0.029206
# 582               -0.001338                0.062094               -0.034751
# 583               -0.000247                0.065654               -0.030552
# 584                0.005144                0.058629               -0.028954
# 585               -0.000593                0.061574               -0.026880
#
#      accel__quantile__q_0.7  accel__quantile__q_0.3  accel__quantile__q_0.9  \
# 0                  0.068060               -0.059695                0.161705
# 1                  0.061888               -0.052954                0.151550
# 2                  0.065461               -0.056284                0.154235
# 3                  0.060913               -0.058314                0.161625
# 4                  0.066761               -0.055471                0.137255
# ..                      ...                     ...                     ...
# 581                0.039039               -0.014951                0.078375
# 582                0.045153               -0.018104                0.085732
# 583                0.048142               -0.014643                0.090108
# 584                0.040697               -0.014091                0.084368
# 585                0.038211               -0.012008                0.090612
#
#      ...  accel__lempel_ziv_complexity__bins_100  \
# 0    ...                                0.579327
# 1    ...                                0.579327
# 2    ...                                0.579327
# 3    ...                                0.564904
# 4    ...                                0.574519
# ..   ...                                     ...
# 581  ...                                0.562500
# 582  ...                                0.579327
# 583  ...                                0.574519
# 584  ...                                0.584135
# 585  ...                                0.580282
#
#      accel__lempel_ziv_complexity__bins_3  \
# 0                                0.209135
# 1                                0.221154
# 2                                0.213942
# 3                                0.206731
# 4                                0.201923
# ..                                    ...
# 581                              0.206731
# 582                              0.216346
# 583                              0.225962
# 584                              0.216346
# 585                              0.202817
#
#      accel__fft_coefficient__attr_"angle"__coeff_81  \
# 0                                         52.494338
# 1                                         45.825681
# 2                                         76.274069
# 3                                         45.867488
# 4                                         22.549382
# ..                                              ...
# 581                                     -141.653908
# 582                                       40.436730
# 583                                      -83.992258
# 584                                      -50.258627
# 585                                       37.383553
#
#      accel__time_reversal_asymmetry_statistic__lag_1  \
# 0                                       1.857280e-04
# 1                                       9.867026e-06
# 2                                       9.384885e-05
# 3                                       1.121850e-04
# 4                                       1.141914e-05
# ..                                               ...
# 581                                    -2.438398e-06
# 582                                     3.386318e-06
# 583                                    -6.068779e-07
# 584                                     6.662942e-06
# 585                                     4.790080e-07
#
#      accel__lempel_ziv_complexity__bins_10  \
# 0                                 0.358173
# 1                                 0.367788
# 2                                 0.362981
# 3                                 0.360577
# 4                                 0.355769
# ..                                     ...
# 581                               0.341346
# 582                               0.358173
# 583                               0.358173
# 584                               0.367788
# 585                               0.360563
#
#      accel__max_langevin_fixed_point__m_3__r_30  \
# 0                                      0.022129
# 1                                      0.596924
# 2                                      0.051861
# 3                                      0.006778
# 4                                      1.165951
# ..                                          ...
# 581                                    0.016695
# 582                                    0.021536
# 583                                    0.014455
# 584                                    0.676177
# 585                                    0.039455
#
#      accel__cwt_coefficients__coeff_11__w_20__widths_(2, 5, 10, 20)  \
# 0                                             0.019542
# 1                                            -0.042134
# 2                                            -0.034419
# 3                                             0.100469
# 4                                             0.017758
# ..                                                 ...
# 581                                           0.061341
# 582                                           0.069268
# 583                                           0.081185
# 584                                           0.088236
# 585                                          -0.016470
#
#      accel__augmented_dickey_fuller__attr_"usedlag"__autolag_"AIC"  \
# 0                                                 18.0
# 1                                                 17.0
# 2                                                 18.0
# 3                                                 17.0
# 4                                                 17.0
# ..                                                 ...
# 581                                               18.0
# 582                                               18.0
# 583                                               17.0
# 584                                               17.0
# 585                                               17.0
#
#      accel__fft_coefficient__attr_"abs"__coeff_57  label
# 0                                        0.144301      1
# 1                                        0.186510      1
# 2                                        0.616713      1
# 3                                        0.441250      1
# 4                                        0.124602      1
# ..                                            ...    ...
# 581                                      0.292314      0
# 582                                      0.364807      0
# 583                                      0.394002      0
# 584                                      0.364683      0
# 585                                      0.426104      0
#
# [586 rows x 300 columns]

# %%
# separate dataset into train and test sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_12k.iloc[:,0:-1], df_12k.iloc[:,-1], test_size=0.2)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

clf = DecisionTreeClassifier()

clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
clf.score(X_test, y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, clf.predict(X_test))
# Out:
# array([[48,  0],
#        [ 0, 69]], dtype=int64)

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(20, 5))
plot_tree(clf, feature_names=X_train.columns)
# Out:
# [Text(0.5, 0.75, 'accel__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.6 <= 0.002\ngini = 0.499\nsamples = 468\nvalue = [244, 224]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 244\nvalue = [244, 0]'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 224\nvalue = [0, 224]')]

# %% [markdown]
# ## Try with minimal feature set

# %%
# extract minimal feature set
from tsfresh.feature_extraction.settings import MinimalFCParameters

minimal_fc = MinimalFCParameters()  # Create dictionary
minimal = sorted(minimal_fc.keys())  # Sort list of dictionary keys
print('Number of feature calculators: ', len(minimal))
print(minimal)
# Out:
# Number of feature calculators:  10
# ['absolute_maximum', 'length', 'maximum', 'mean', 'median', 'minimum', 'root_mean_square', 'standard_deviation', 'sum_values', 'variance']

# %%
X_f12k = extract_features(fault_12k, column_id='id', column_sort='time',
                    default_fc_parameters=minimal_fc)
X_n12k = extract_features(normal_12k, column_id='id', column_sort='time',
                    default_fc_parameters=minimal_fc)
# Out:
# Feature Extraction: 100%|██████████████████████████████████████████████████████████████| 20/20 [00:06<00:00,  2.97it/s]
# Feature Extraction: 100%|██████████████████████████████████████████████████████████████| 20/20 [00:05<00:00,  3.90it/s]

# %%
X_12k = pd.concat([X_f12k, X_n12k], ignore_index=True)
X_12k_real = X_12k.dropna(axis=1) # drop columns with NaN

# %%
select.fit(X_12k_real, np.squeeze(y_12k))
# Out:
# FeatureSelector()

# %%
X_12k_rel = select.transform(X_12k_real)
X_12k_rel.shape
# Out:
# (586, 9)

# %%
X_12k_rel['label'] = np.int32(y_12k)
X_12k_rel.to_csv('12k_proc_min.csv', index=False)

# %%
df_12k_min = pd.read_csv('12k_proc_min.csv')

# %%
X_train, X_test, y_train, y_test = train_test_split(df_12k_min.iloc[:,0:-1], df_12k_min.iloc[:,-1], test_size=0.2)

# %%
clf = DecisionTreeClassifier()

clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 1.0

# %%
plot_tree(clf, feature_names=X_train.columns)
# Out:
# [Text(0.5, 0.75, 'accel__root_mean_square <= 0.085\ngini = 0.5\nsamples = 468\nvalue = [235, 233]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 235\nvalue = [235, 0]'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 233\nvalue = [0, 233]')]
